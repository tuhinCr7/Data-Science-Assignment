# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/Users/tuhinalambijoy/Downloads/final_data.csv")
df
# Out:
#      age  annual_income  financial_responsibility  on-time_payment  \
# 0     56         780.24                         6            68.11
# 1     46        1657.77                         2            86.29
# 2     32         658.35                         7            94.72
# 3     60        1426.70                         3            76.01
# 4     25        1568.41                         3            76.01
# ..   ...            ...                       ...              ...
# 995   22         978.50                         6            95.78
# 996   40         761.27                         1            80.82
# 997   27        1111.06                         8            62.31
# 998   61         991.12                         7            84.53
# 999   19         390.20                         9            79.84
#
#      credit_utilization  credit_score
# 0                 50.16           646
# 1                  9.86           850
# 2                 68.35           656
# ...

# %% [markdown]
# cheaking is there any coreaton between credit score and on time payment

# %%
df[['credit_score', 'on-time_payment']].corr()
# Out:
#                  credit_score  on-time_payment
# credit_score         1.000000         0.138339
# on-time_payment      0.138339         1.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df['credit_score'], df['on-time_payment'])
plt.xlabel("Credit Score")
plt.ylabel("On-Time Payment (%)")
plt.title("Relationship between Credit Score and On-Time Payment")
plt.show()
